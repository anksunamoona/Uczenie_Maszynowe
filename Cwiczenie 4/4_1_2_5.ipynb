# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/palles77/MachineLearning_Exercise4/main/Employee_Compensation_SF.csv')

# %%
# function returning column index in a dataframe
def column_index(df, query_cols):
    cols = df.columns.values
    sidx = np.argsort(cols)
    return sidx[np.searchsorted(cols,query_cols,sorter=sidx)]

# reading 'Total Benefits' -> column 20, 'Total Compensation' -> column 21
(column_first, colum_second) = column_index(dataset, ['Total Salary', 'Retirement'])
# get sample 1000 rows
dataset_for_clustering = dataset.sample(1000).iloc[:, [column_first, colum_second]].values
X = dataset_for_clustering
# Drawing dendrogram
dendrogram = sch.dendrogram(sch.linkage(dataset_for_clustering, method='ward'))

# %%
model = AgglomerativeClustering(n_clusters=12, metric='cosine', linkage='complete')
model.fit(X)
labels = model.labels_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-123d976c4424> in <cell line: 2>()
#       1 model = AgglomerativeClustering(n_clusters=12, metric='cosine', linkage='complete')
# ----> 2 model.fit(X)
#       3 labels = model.labels_
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py in fit(self, X, y)
#     954         self._validate_params()
#     955         X = self._validate_data(X, ensure_min_samples=2)
# --> 956         return self._fit(X)
#     957
#     958     def _fit(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py in _fit(self, X)
#    1044         return_distance = (distance_threshold is not None) or self.compute_distances
#    1045
# -> 1046         out = memory.cache(tree_builder)(
#    1047             X,
#    1048             connectivity=connectivity,
#
# /usr/local/lib/python3.10/dist-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     351
#     352     def __call__(self, *args, **kwargs):
# --> 353         return self.func(*args, **kwargs)
#     354
#     355     def call_and_shelve(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py in _complete_linkage(*args, **kwargs)
#     663 def _complete_linkage(*args, **kwargs):
#     664     kwargs["linkage"] = "complete"
# --> 665     return linkage_tree(*args, **kwargs)
#     666
#     667
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py in linkage_tree(X, connectivity, n_clusters, linkage, affinity, return_distance)
#     487
#     488     if affinity == "cosine" and np.any(~np.any(X, axis=1)):
# --> 489         raise ValueError("Cosine affinity cannot be used when X contains zero vectors")
#     490
#     491     if connectivity is None:
#
# ValueError: Cosine affinity cannot be used when X contains zero vectors

# %%
# Drawing Clusters
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
plt.scatter(X[labels==3, 0], X[labels==3, 1], s=50, marker='o', color='purple')
plt.scatter(X[labels==4, 0], X[labels==4, 1], s=50, marker='o', color='orange')
plt.scatter(X[labels==5, 0], X[labels==5, 1], s=50, marker='o', color='pink')
plt.scatter(X[labels==6, 0], X[labels==6, 1], s=50, marker='o', color='brown')
plt.scatter(X[labels==7, 0], X[labels==7, 1], s=50, marker='o', color='yellow')
plt.scatter(X[labels==8, 0], X[labels==8, 1], s=50, marker='o', color='black')
plt.scatter(X[labels==9, 0], X[labels==9, 1], s=50, marker='o', color='darkblue')
plt.scatter(X[labels==10, 0], X[labels==10, 1], s=50, marker='o', color='gray')
plt.scatter(X[labels==11, 0], X[labels==11, 1], s=50, marker='o', color='lightblue')
plt.xlabel('Total Salary')
plt.ylabel('Retirement')
plt.show()
